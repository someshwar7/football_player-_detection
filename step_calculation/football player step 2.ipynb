# %%
import cv2
import numpy as np
from ultralytics import YOLO
from scipy.spatial.distance import cdist
from collections import deque
import colorsys
import os

class PlayerTracker:
    def __init__(self, player_id, initial_position, team):
        self.id = player_id
        self.positions = deque(maxlen=30)  # Store last 30 positions
        self.positions.append(initial_position)
        self.step_count = 0
        self.team = team
        self.color = self.generate_color()
        self.velocity = [0, 0]
        self.last_step_time = 0

    def generate_color(self):
        hue = self.id * 0.1 % 1.0
        return tuple(int(x * 255) for x in colorsys.hsv_to_rgb(hue, 0.8, 1.0))

    def update_position(self, new_position, current_time):
        if self.positions:
            self.velocity = [new_position[0] - self.positions[-1][0],
                             new_position[1] - self.positions[-1][1]]
        self.positions.append(new_position)
        self.update_step_count(current_time)

    def update_step_count(self, current_time):
        if len(self.positions) < 2:
            return

        # Calculate acceleration
        if len(self.positions) >= 3:
            prev_velocity = [self.positions[-2][0] - self.positions[-3][0],
                             self.positions[-2][1] - self.positions[-3][1]]
            acceleration = [self.velocity[0] - prev_velocity[0],
                            self.velocity[1] - prev_velocity[1]]
            acceleration_magnitude = np.linalg.norm(acceleration)

            # Detect step based on acceleration peak
            if acceleration_magnitude > 0.5 and (current_time - self.last_step_time) > 0.2:  # Adjust thresholds as needed
                self.step_count += 1
                self.last_step_time = current_time

def detect_team(frame, bbox):
    x1, y1, x2, y2 = map(int, bbox[:4])
    roi = frame[y1:y2, x1:x2]
    hsv = cv2.cvtColor(roi, cv2.COLOR_BGR2HSV)
    
    # Define color ranges for team jerseys (adjust these based on actual jersey colors)
    team1_lower = np.array([0, 100, 100])  # Red for team 1
    team1_upper = np.array([10, 255, 255])
    team2_lower = np.array([100, 100, 100])  # Blue for team 2
    team2_upper = np.array([130, 255, 255])
    
    mask1 = cv2.inRange(hsv, team1_lower, team1_upper)
    mask2 = cv2.inRange(hsv, team2_lower, team2_upper)
    
    return 1 if np.sum(mask1) > np.sum(mask2) else 2
def main():
    # Specify the input video path directly in the code
    input_video_path = "E:/DS project/Football Player Detection/08fd33_4.mp4"
    # Validate the input video path
    if not os.path.exists(input_video_path):
        print(f"Error: The file {input_video_path} does not exist.")
        return

    # Specify the output video path on disk E
    output_video_path = "E:/output_video4.mp4"

    model = YOLO('yolov8n.pt')
    video = cv2.VideoCapture(input_video_path)
    
    if not video.isOpened():
        print(f"Error: Unable to open video file {input_video_path}")
        return

    fps = video.get(cv2.CAP_PROP_FPS)
    width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
    
    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))
    
    if not out.isOpened():
        print(f"Error: Unable to create output video file {output_video_path}")
        video.release()
        return

    players = {}
    next_id = 0

    while True:
        ret, frame = video.read()
        if not ret:
            break

        current_time = video.get(cv2.CAP_PROP_POS_MSEC) / 1000.0  # Current time in seconds
        results = model(frame)

        # Process detections
        detections = results[0].boxes.data
        for detection in detections:
            bbox = detection[:4].tolist()
            conf, class_id = detection[4:6]
            if int(class_id) == 0:  # Assuming 0 is the class ID for person
                center = ((bbox[0] + bbox[2]) / 2, (bbox[1] + bbox[3]) / 2)
                team = detect_team(frame, bbox)

                if not players:
                    players[next_id] = PlayerTracker(next_id, center, team)
                    next_id += 1
                else:
                    distances = cdist([center], [p.positions[-1] for p in players.values()])
                    closest_player_id = min(players.keys(), key=lambda i: distances[0][i])
                    
                    if distances[0][closest_player_id] < 50:  # Adjust threshold as needed
                        players[closest_player_id].update_position(center, current_time)
                    else:
                        players[next_id] = PlayerTracker(next_id, center, team)
                        next_id += 1

        # Visualize results
        for player in players.values():
            if player.positions:
                cv2.putText(frame, f"Player {player.id} (Team {player.team}): {player.step_count} steps", 
                            (int(player.positions[-1][0]), int(player.positions[-1][1])), 
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, player.color, 2)

        # Write the frame to the output video
        out.write(frame)

        # Display the frame
        cv2.imshow('Football Player Tracking', frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    video.release()
    out.release()
    cv2.destroyAllWindows()

    print(f"Output video saved as: {output_video_path}")

    # Print final step counts
    for player_id, player in players.items():
        print(f"Player {player_id} (Team {player.team}): {player.step_count} steps")

if __name__ == "__main__":
    main()
# Out:
# 0: 384x640 21 persons, 107.4ms
# Speed: 6.0ms preprocess, 107.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 70.5ms
# Speed: 4.0ms preprocess, 70.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 68.5ms
# Speed: 1.0ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 66.5ms
# Speed: 3.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 71.8ms
# Speed: 1.5ms preprocess, 71.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 76.5ms
# Speed: 2.3ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 car, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 car, 76.4ms
# Speed: 2.0ms preprocess, 76.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 65.1ms
# Speed: 2.1ms preprocess, 65.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 car, 86.8ms
# Speed: 3.1ms preprocess, 86.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 car, 68.3ms
# Speed: 2.0ms preprocess, 68.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 car, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 car, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 car, 73.8ms
# Speed: 3.3ms preprocess, 73.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 70.5ms
# Speed: 2.0ms preprocess, 70.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 72.3ms
# Speed: 3.0ms preprocess, 72.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 65.9ms
# Speed: 3.4ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 sports ball, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 72.9ms
# Speed: 4.0ms preprocess, 72.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 car, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 car, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 66.6ms
# Speed: 2.0ms preprocess, 66.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 67.7ms
# Speed: 1.0ms preprocess, 67.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 71.9ms
# Speed: 2.2ms preprocess, 71.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 car, 65.4ms
# Speed: 1.5ms preprocess, 65.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 car, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 sports ball, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 66.4ms
# Speed: 2.0ms preprocess, 66.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 79.4ms
# Speed: 6.0ms preprocess, 79.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 65.5ms
# Speed: 4.0ms preprocess, 65.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 66.9ms
# Speed: 2.0ms preprocess, 66.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 68.6ms
# Speed: 3.2ms preprocess, 68.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 66.5ms
# Speed: 3.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 sports ball, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 sports ball, 56.0ms
# Speed: 1.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 sports ball, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 sports ball, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 sports ball, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 1 sports ball, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 sports ball, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 sports ball, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 sports ball, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 sports ball, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 1 bench, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 1 sports ball, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 sports ball, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 1 sports ball, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 sports ball, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 sports ball, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 66.5ms
# Speed: 3.0ms preprocess, 66.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 74.5ms
# Speed: 2.0ms preprocess, 74.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 sports ball, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 truck, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 1 truck, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 truck, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 1 truck, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 truck, 59.5ms
# Speed: 4.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 70.5ms
# Speed: 3.0ms preprocess, 70.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 58.5ms
# Speed: 1.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 55.5ms
# Speed: 1.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 60.5ms
# Speed: 1.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 58.2ms
# Speed: 3.0ms preprocess, 58.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 54.0ms
# Speed: 3.0ms preprocess, 54.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 72.5ms
# Speed: 2.0ms preprocess, 72.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 56.9ms
# Speed: 2.0ms preprocess, 56.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 54.3ms
# Speed: 2.0ms preprocess, 54.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 60.0ms
# Speed: 3.5ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 59.7ms
# Speed: 2.0ms preprocess, 59.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 58.0ms
# Speed: 4.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 55.0ms
# Speed: 3.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 71.0ms
# Speed: 3.0ms preprocess, 71.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 54.0ms
# Speed: 2.0ms preprocess, 54.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 58.4ms
# Speed: 3.0ms preprocess, 58.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 58.0ms
# Speed: 1.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 58.0ms
# Speed: 1.5ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 55.5ms
# Speed: 4.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 68.0ms
# Speed: 3.5ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 60.0ms
# Speed: 3.2ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 69.5ms
# Speed: 4.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 58.5ms
# Speed: 1.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 59.5ms
# Speed: 1.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 53.5ms
# Speed: 3.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 72.5ms
# Speed: 2.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 60.5ms
# Speed: 1.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 54.2ms
# Speed: 2.0ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 59.5ms
# Speed: 1.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 71.5ms
# Speed: 3.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 56.0ms
# Speed: 1.5ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 64.1ms
# Speed: 3.0ms preprocess, 64.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 58.9ms
# Speed: 3.0ms preprocess, 58.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 63.5ms
# Speed: 4.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 58.5ms
# Speed: 1.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 57.4ms
# Speed: 3.0ms preprocess, 57.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 56.0ms
# Speed: 4.0ms preprocess, 56.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 73.8ms
# Speed: 3.0ms preprocess, 73.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 61.5ms
# Speed: 4.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 54.5ms
# Speed: 2.0ms preprocess, 54.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 57.5ms
# Speed: 3.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 59.5ms
# Speed: 3.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 56.5ms
# Speed: 3.0ms preprocess, 56.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 72.5ms
# Speed: 4.0ms preprocess, 72.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 60.5ms
# Speed: 1.0ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 57.0ms
# Speed: 2.5ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 58.0ms
# Speed: 2.5ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 60.0ms
# Speed: 3.5ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 58.0ms
# Speed: 2.5ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 60.0ms
# Speed: 2.5ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 57.8ms
# Speed: 3.0ms preprocess, 57.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 56.0ms
# Speed: 2.0ms preprocess, 56.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 59.8ms
# Speed: 4.0ms preprocess, 59.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 51.0ms
# Speed: 3.0ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 58.1ms
# Speed: 3.0ms preprocess, 58.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 57.0ms
# Speed: 3.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 66.5ms
# Speed: 3.0ms preprocess, 66.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 66.9ms
# Speed: 3.0ms preprocess, 66.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 persons, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 persons, 57.0ms
# Speed: 1.0ms preprocess, 57.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 56.5ms
# Speed: 1.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 53.5ms
# Speed: 4.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 persons, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 persons, 54.5ms
# Speed: 3.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 55.5ms
# Speed: 3.0ms preprocess, 55.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 tv, 55.5ms
# ...
#
# 0: 384x640 12 persons, 1 train, 120.1ms
# Speed: 4.0ms preprocess, 120.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 115.3ms
# Speed: 5.0ms preprocess, 115.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 118.1ms
# Speed: 4.0ms preprocess, 118.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 train, 116.2ms
# Speed: 4.5ms preprocess, 116.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 train, 117.5ms
# Speed: 5.0ms preprocess, 117.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 train, 115.5ms
# Speed: 5.0ms preprocess, 115.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 train, 124.5ms
# Speed: 4.0ms preprocess, 124.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 train, 120.1ms
# Speed: 4.0ms preprocess, 120.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 train, 123.5ms
# Speed: 5.0ms preprocess, 123.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 1 train, 118.5ms
# Speed: 4.0ms preprocess, 118.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 116.5ms
# Speed: 4.0ms preprocess, 116.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 train, 116.6ms
# Speed: 5.0ms preprocess, 116.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 train, 121.5ms
# Speed: 5.0ms preprocess, 121.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 train, 123.1ms
# Speed: 5.0ms preprocess, 123.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 train, 145.5ms
# Speed: 4.0ms preprocess, 145.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 117.5ms
# Speed: 4.0ms preprocess, 117.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 125.5ms
# Speed: 4.0ms preprocess, 125.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 train, 116.5ms
# Speed: 4.0ms preprocess, 116.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 train, 154.9ms
# Speed: 5.0ms preprocess, 154.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 train, 128.6ms
# Speed: 4.0ms preprocess, 128.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 train, 121.9ms
# Speed: 5.0ms preprocess, 121.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 train, 116.5ms
# Speed: 4.0ms preprocess, 116.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 persons, 1 train, 121.5ms
# Speed: 4.0ms preprocess, 121.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 1 bus, 1 train, 115.1ms
# Speed: 3.0ms preprocess, 115.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 bus, 1 train, 124.5ms
# Speed: 4.5ms preprocess, 124.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 bus, 1 train, 114.5ms
# Speed: 4.0ms preprocess, 114.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 1 train, 113.5ms
# Speed: 4.0ms preprocess, 113.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 1 train, 118.5ms
# Speed: 5.0ms preprocess, 118.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 117.5ms
# Speed: 4.0ms preprocess, 117.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 train, 146.1ms
# Speed: 4.0ms preprocess, 146.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 133.8ms
# Speed: 5.0ms preprocess, 133.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 persons, 160.1ms
# Speed: 5.0ms preprocess, 160.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 182.0ms
# Speed: 5.0ms preprocess, 182.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 193.1ms
# Speed: 5.0ms preprocess, 193.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 171.6ms
# Speed: 5.0ms preprocess, 171.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 156.7ms
# Speed: 5.5ms preprocess, 156.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 158.1ms
# Speed: 5.0ms preprocess, 158.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 156.2ms
# Speed: 5.0ms preprocess, 156.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 138.6ms
# Speed: 5.0ms preprocess, 138.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 149.1ms
# Speed: 4.0ms preprocess, 149.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 138.0ms
# Speed: 3.9ms preprocess, 138.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 142.1ms
# Speed: 5.0ms preprocess, 142.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 bus, 141.7ms
# Speed: 4.5ms preprocess, 141.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 139.5ms
# Speed: 4.0ms preprocess, 139.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 174.3ms
# Speed: 6.0ms preprocess, 174.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 167.1ms
# Speed: 5.0ms preprocess, 167.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 car, 159.6ms
# Speed: 5.0ms preprocess, 159.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 168.6ms
# Speed: 5.0ms preprocess, 168.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 car, 173.5ms
# Speed: 4.1ms preprocess, 173.5ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 1 car, 153.6ms
# Speed: 5.1ms preprocess, 153.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 159.1ms
# Speed: 5.0ms preprocess, 159.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 161.5ms
# Speed: 4.0ms preprocess, 161.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 1 car, 158.0ms
# Speed: 5.0ms preprocess, 158.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 1 car, 155.6ms
# Speed: 5.0ms preprocess, 155.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 1 car, 155.1ms
# Speed: 4.0ms preprocess, 155.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 160.9ms
# Speed: 5.0ms preprocess, 160.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 58.5ms
# Speed: 2.0ms preprocess, 58.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 61.5ms
# Speed: 3.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 57.3ms
# Speed: 1.9ms preprocess, 57.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 59.5ms
# Speed: 3.1ms preprocess, 59.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 1 potted plant, 52.5ms
# Speed: 2.0ms preprocess, 52.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 persons, 55.6ms
# Speed: 2.0ms preprocess, 55.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 53.2ms
# Speed: 3.0ms preprocess, 53.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 54.5ms
# Speed: 1.0ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 52.7ms
# Speed: 3.0ms preprocess, 52.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 56.4ms
# Speed: 1.9ms preprocess, 56.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 56.4ms
# Speed: 3.0ms preprocess, 56.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 60.1ms
# Speed: 2.9ms preprocess, 60.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 52.7ms
# Speed: 2.1ms preprocess, 52.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 52.9ms
# Speed: 3.1ms preprocess, 52.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 53.1ms
# Speed: 3.0ms preprocess, 53.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 55.1ms
# Speed: 3.0ms preprocess, 55.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 persons, 56.0ms
# Speed: 1.9ms preprocess, 56.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 52.0ms
# Speed: 2.0ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 50.8ms
# Speed: 2.2ms preprocess, 50.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 52.0ms
# Speed: 3.0ms preprocess, 52.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 persons, 55.0ms
# Speed: 2.0ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 59.2ms
# Speed: 1.0ms preprocess, 59.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 persons, 56.4ms
# Speed: 2.1ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 55.9ms
# Speed: 2.1ms preprocess, 55.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 52.8ms
# Speed: 3.0ms preprocess, 52.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 56.8ms
# Speed: 3.0ms preprocess, 56.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 55.7ms
# Speed: 1.0ms preprocess, 55.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 persons, 58.6ms
# Speed: 1.9ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 persons, 53.8ms
# Speed: 2.0ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 55.7ms
# Speed: 3.0ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 52.1ms
# Speed: 3.0ms preprocess, 52.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 57.2ms
# Speed: 3.0ms preprocess, 57.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 52.9ms
# Speed: 3.1ms preprocess, 52.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 55.0ms
# Speed: 1.9ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 persons, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 persons, 53.3ms
# Speed: 1.1ms preprocess, 53.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 53.5ms
# Speed: 2.0ms preprocess, 53.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 persons, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 persons, 50.0ms
# Speed: 3.0ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Output video saved as: E:/output_video4.mp4
# Player 0 (Team 2): 19 steps
# Player 1 (Team 2): 101 steps
# Player 2 (Team 2): 107 steps
# Player 3 (Team 2): 40 steps
# Player 4 (Team 2): 55 steps
# Player 5 (Team 2): 78 steps
# Player 6 (Team 2): 115 steps
# Player 7 (Team 2): 116 steps
# Player 8 (Team 2): 83 steps
# Player 9 (Team 2): 41 steps
# Player 10 (Team 2): 8 steps
# Player 11 (Team 2): 111 steps
# Player 12 (Team 2): 21 steps
# Player 13 (Team 2): 30 steps
# Player 14 (Team 2): 23 steps
# Player 15 (Team 2): 83 steps
# Player 16 (Team 2): 115 steps
# Player 17 (Team 2): 29 steps
# Player 18 (Team 2): 16 steps
# Player 19 (Team 1): 1 steps
# Player 20 (Team 2): 27 steps
# Player 21 (Team 2): 33 steps
# Player 22 (Team 2): 6 steps
# Player 23 (Team 2): 44 steps
# Player 24 (Team 2): 1 steps
# Player 25 (Team 1): 7 steps
# Player 26 (Team 2): 1 steps
# Player 27 (Team 2): 105 steps
# Player 28 (Team 2): 99 steps
# Player 29 (Team 2): 12 steps
# Player 30 (Team 2): 96 steps
# Player 31 (Team 2): 11 steps
# Player 32 (Team 2): 40 steps
# Player 33 (Team 2): 53 steps
# Player 34 (Team 1): 5 steps
# Player 35 (Team 2): 2 steps
# Player 36 (Team 2): 1 steps
# Player 37 (Team 2): 39 steps
# Player 38 (Team 2): 8 steps
# Player 39 (Team 2): 83 steps
# Player 40 (Team 2): 8 steps
# Player 41 (Team 1): 0 steps
# Player 42 (Team 2): 1 steps
# Player 43 (Team 2): 24 steps
# Player 44 (Team 2): 1 steps
# Player 45 (Team 2): 55 steps
# Player 46 (Team 2): 47 steps
# Player 47 (Team 2): 30 steps
# Player 48 (Team 1): 0 steps
# Player 49 (Team 2): 62 steps
# Player 50 (Team 1): 0 steps
# Player 51 (Team 2): 35 steps
# Player 52 (Team 2): 20 steps
# Player 53 (Team 2): 44 steps
# Player 54 (Team 2): 36 steps
# Player 55 (Team 2): 8 steps
# Player 56 (Team 2): 15 steps
# Player 57 (Team 2): 51 steps
# Player 58 (Team 1): 0 steps
# Player 59 (Team 2): 36 steps
# Player 60 (Team 2): 11 steps
# Player 61 (Team 1): 0 steps
# Player 62 (Team 2): 34 steps
# Player 63 (Team 2): 1 steps
# Player 64 (Team 2): 2 steps
# Player 65 (Team 2): 15 steps
# Player 66 (Team 2): 1 steps
# Player 67 (Team 2): 4 steps
# Player 68 (Team 2): 0 steps
# Player 69 (Team 2): 4 steps
# Player 70 (Team 1): 12 steps
# Player 71 (Team 2): 9 steps
# Player 72 (Team 2): 8 steps
# Player 73 (Team 2): 0 steps
# Player 74 (Team 2): 4 steps
# Player 75 (Team 2): 1 steps
# Player 76 (Team 2): 0 steps
# Player 77 (Team 2): 2 steps
# Player 78 (Team 2): 0 steps
